# %% [markdown]
# # Vehicle Classification
#
# ## Exploratory Data Analysis

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Collecting numpy>=1.21.2
#   Downloading numpy-1.22.4-cp310-cp310-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.22.4 opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# !pip install pandas
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      -------------------------------------- 930.9/930.9 KB 2.7 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.22.4)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.1-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 3.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp310-cp310-win_amd64.whl (55 kB)
#      -------------------------------------- 55.3/55.3 KB 959.1 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.2 pillow-9.1.1
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import os

import cv2
import matplotlib.pyplot as plt
import pandas            as pd

# %% [markdown]
# ### Load dataset

# %%
labels = pd.read_csv('../data/car_dataset_labels.csv')
labels.head()
# Out:
#      img_name                       class subset
# 0  000001.jpg  AM General Hummer SUV 2000  train
# 1  000002.jpg  AM General Hummer SUV 2000  train
# 2  000003.jpg  AM General Hummer SUV 2000  train
# 3  000004.jpg  AM General Hummer SUV 2000  train
# 4  000005.jpg  AM General Hummer SUV 2000  train

# %% [markdown]
# ### Get some stats
#
# Complete the function `get_stats()` below:

# %%
def get_stats(df):
    """
    Check number of:
        1. Classes
        2. Training samples
        3. Testing samples
    """
    # Put here the number of classes 
    class_num = df['class'].unique().shape[0]
    
    # Put here the number of training images 
    train_num = df[df['subset']=='train'].shape[0]
    
    # Put here the number of test images 
    test_num = df[df['subset']=='test'].shape[0]

    return class_num, train_num, test_num

# %%
# Don't change this cell
class_num, train_num, test_num = get_stats(labels)
print(f'Our dataset has {class_num} classes, {train_num} train images, {test_num} test images')
# Out:
# Our dataset has 196 classes, 8144 train images, 8041 test images

# %% [markdown]
# ## Working with images and OpenCV

# %%
# Load an image
img = cv2.imread('../data/car_ims/000039.jpg')

print(f'Image type: {type(img)}')
print(f'Image shape: {img.shape} (Height x Width x Channels)')
print(f'Image min value: {img.min()}')
print(f'Image max value: {img.max()}')
# Out:
# Image type: <class 'numpy.ndarray'>
# Image shape: (384, 512, 3) (Height x Width x Channels)
# Image min value: 0
# Image max value: 255

# %% [markdown]
# **Important Note:** An image loaded using OpenCV is just a Numpy array, keep in mind you can make use of all the numpy functionalities you know here.

# %%
# We can access to pixel values
px = img[100,100] 
print(px)
# Out:
# [150 171 102]

# %%
# Display
plt.imshow(img)
plt.show()

# %% [markdown]
# **Important Note:** OpenCV uses BGR format while matplotlib uses RGB.

# %%
# Convert from RGB to RGB first
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Then display the converted image
plt.imshow(img_rgb)
plt.show()

# %%
# Crop and extract a certain region from an image
crop = img_rgb[50:145, 35:190]
plt.imshow(crop)
plt.show()

# %% [markdown]
# ## Load and display some images and their label

# %%
sampled_rows = labels.sample(20, replace=False, random_state=123)
for _, row in sampled_rows.iterrows():
    im = cv2.imread(os.path.join('../data/car_ims', row["img_name"]))
    im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    plt.imshow(im_rgb)
    plt.title(f'{row["class"]} - {row["img_name"]}')
    plt.show()
